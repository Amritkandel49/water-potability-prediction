# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.curdir
# Out:
# '.'

# %%
# !pwd
# Out:
# /content

# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/water_potability_prediction/water_potability.csv')
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df = shuffle(df)
df.head()
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 2970  10.933111  162.424918  18846.634913     7.085261         NaN
# 1532   6.028101  262.808478  17150.100550     9.378390  380.301350
# 1656   5.575921  223.374007  14553.132308     9.689175  234.609808
# 1173   6.320428  210.310043  11682.229317     6.968423  311.777822
# 2359   7.851926  235.338312  14763.580113     7.741975  338.603322
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2970    593.725764       14.977233        60.690580   3.894989           0
# 1532    514.545672       20.637599        76.529077   4.080786           1
# 1656    252.968328       12.249489        59.523003   4.294448           0
# 1173    375.964558       11.973422        62.960463   4.553381           1
# 2359    505.665639       11.863370        49.598381   5.204044           1

# %%
df.head(50)
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 2970  10.933111  162.424918  18846.634913     7.085261         NaN
# 1532   6.028101  262.808478  17150.100550     9.378390  380.301350
# 1656   5.575921  223.374007  14553.132308     9.689175  234.609808
# 1173   6.320428  210.310043  11682.229317     6.968423  311.777822
# 2359   7.851926  235.338312  14763.580113     7.741975  338.603322
# 2778   4.886380  159.317972  38633.305169     8.370179  375.899169
# 646         NaN  221.620058  11954.700730     6.657053         NaN
# 313    5.862641  185.065220  44069.272158     4.382721  412.690111
# 2312   6.266378  163.385405  28141.216497     8.508751  376.870555
# 2475   4.991397  141.622395  44499.728710     8.260928  335.509830
# 3270   6.069616  186.659040  26138.780191     7.747547  345.700257
# 581    7.895046  174.692685  10465.261601     7.668315  350.535418
# 47    10.682966  173.375498  15758.740621     5.570784  307.352586
# ...

# %%
df.shape
# Out:
# (3276, 10)

# %%
df_train = df.iloc[:2621]
df_train.shape
# Out:
# (2621, 10)

# %%
df_test = df.iloc[2621:]
df_test.shape
# Out:
# (655, 10)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 655 entries, 271 to 147
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               567 non-null    float64
#  1   Hardness         655 non-null    float64
#  2   Solids           655 non-null    float64
#  3   Chloramines      655 non-null    float64
#  4   Sulfate          489 non-null    float64
#  5   Conductivity     655 non-null    float64
#  6   Organic_carbon   655 non-null    float64
#  7   Trihalomethanes  626 non-null    float64
#  8   Turbidity        655 non-null    float64
#  9   Potability       655 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 56.3 KB

# %%
df_test.isnull().sum()
# Out:
# ph                  88
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            166
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes     29
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df_train.isnull().sum()
# Out:
# ph                 403
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            615
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    133
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df_train.to_csv('/content/drive/MyDrive/Colab Notebooks/water_potability_prediction/dataset/train.csv', index=False)

# %%
df_test.to_csv('/content/drive/MyDrive/Colab Notebooks/water_potability_prediction/dataset/test.csv', index=False)
